# %%
import os;
from google.colab import drive;
import pandas as pd;

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.getcwd()
# Out:
# '/content'

# %%
folderPath = '/content/drive/My Drive/Python_Midterm_Files';

# %%
os.chdir(folderPath);

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Python_Midterm_Files'

# %%
ls
# Out:
# '311_Request_NYC_Data Dictionary.xlsx'       __init__.py
#  311_Service_Request_json_format_data.json   NYCUtility.py
#  311_Service_Requests.csv                    __pycache__/

# %%
import NYCUtility as nyc

# %%
nycRequestDframeOp = nyc.NYCRequestDframeOp();
nycRequestDataPlot = nyc.NYCRequestDataPlot();

# %%
#1. Loading data in to DataFrames from CSV with file Handling and Exception handling
df_csv_data_311_resquests_nyc = nycRequestDframeOp.readCSVDatatoDataFrame();
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DtypeWarning: Columns (20,31,32,36) have mixed types.Specify dtype option on import or set low_memory=False.

# %%
df_csv_data_311_resquests_nyc.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    52934953  01/01/2022 12:00:10 AM  01/01/2022 01:00:11 AM   NYPD
# 1    52933158  01/01/2022 12:00:57 AM  01/01/2022 12:58:22 AM   NYPD
# 2    52938624  01/01/2022 12:01:04 AM  01/01/2022 12:18:49 AM   NYPD
# 3    52931678  01/01/2022 12:01:17 AM  01/01/2022 02:55:16 AM   NYPD
# 4    52934960  01/01/2022 12:01:20 AM  01/01/2022 12:07:25 AM   NYPD
#
#                        Agency Name           Complaint Type        Descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department      Noise - Residential      Loud Talking
# 2  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 3  New York City Police Department      Noise - Residential  Loud Music/Party
# 4  New York City Police Department      Noise - Residential  Loud Music/Party
#
#                 Location Type  Incident Zip      Incident Address  ...  \
# ...

# %%
df_csv_data_311_resquests_nyc.head(10)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    52934953  01/01/2022 12:00:10 AM  01/01/2022 01:00:11 AM   NYPD
# 1    52933158  01/01/2022 12:00:57 AM  01/01/2022 12:58:22 AM   NYPD
# 2    52938624  01/01/2022 12:01:04 AM  01/01/2022 12:18:49 AM   NYPD
# 3    52931678  01/01/2022 12:01:17 AM  01/01/2022 02:55:16 AM   NYPD
# 4    52934960  01/01/2022 12:01:20 AM  01/01/2022 12:07:25 AM   NYPD
# 5    52934948  01/01/2022 12:01:25 AM  01/01/2022 12:26:49 AM   NYPD
# 6    52933243  01/01/2022 12:01:47 AM  01/01/2022 12:19:05 AM   NYPD
# 7    52934735  01/01/2022 12:02:20 AM  01/01/2022 12:52:25 AM   NYPD
# 8    52936729  01/01/2022 12:02:21 AM  01/01/2022 12:49:06 AM   NYPD
# 9    52933081  01/01/2022 12:02:25 AM  01/01/2022 12:59:28 AM   NYPD
#
#                        Agency Name           Complaint Type        Descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# ...

# %%
df_csv_data_311_resquests_nyc.tail()
# Out:
#          Unique Key            Created Date Closed Date Agency  \
# 2687359    55891527  11/04/2022 12:00:00 PM         NaN   DSNY
# 2687360    55883085  11/04/2022 12:00:00 PM         NaN   DSNY
# 2687361    55886682  11/04/2022 12:00:00 PM         NaN   DSNY
# 2687362    55886681  11/04/2022 12:00:00 PM         NaN   DSNY
# 2687363    55884310  11/04/2022 12:00:00 PM         NaN   DSNY
#
#                       Agency Name     Complaint Type         Descriptor  \
# 2687359  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2687360  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2687361  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2687362  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2687363  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
#
#         Location Type  Incident Zip    Incident Address  ... Vehicle Type  \
# 2687359        Street           NaN                 NaN  ...          NaN
# ...

# %%
df_csv_data_311_resquests_nyc.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
#2. Check the Data Types of your data columns.
df_csv_data_311_resquests_nyc.dtypes
# Out:
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                      float64
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                           object
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Description             object
# ...

# %%
#Use of different file formats like json, xml with CSV or Excel. To demonstrate your knowledge on handling structured and unstructured data.
df_json_data_311_resquests_nyc = nycRequestDframeOp.readJSONDatatoDataFrame();

# %%
#13. Select a slice or part of the data and display.
df_json_data_311_resquests_nyc = nycRequestDframeOp.sliceRequiredDataFromDFrame(df_json_data_311_resquests_nyc);

df_json_data_311_resquests_nyc.head()
# Out:
#          8                    9                    10    11  \
# 0  52934953  2022-01-01T00:00:10  2022-01-01T01:00:11  NYPD
# 1  52933158  2022-01-01T00:00:57  2022-01-01T00:58:22  NYPD
# 2  52938624  2022-01-01T00:01:04  2022-01-01T00:18:49  NYPD
# 3  52931678  2022-01-01T00:01:17  2022-01-01T02:55:16  NYPD
# 4  52934960  2022-01-01T00:01:20  2022-01-01T00:07:25  NYPD
#
#                                 12                       13                14  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department      Noise - Residential      Loud Talking
# 2  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 3  New York City Police Department      Noise - Residential  Loud Music/Party
# 4  New York City Police Department      Noise - Residential  Loud Music/Party
#
#                            15     16                    17  ...    39    40  \
# ...

# %%
df_json_data_311_resquests_nyc = nycRequestDframeOp.renameDataFrameColNames(df_json_data_311_resquests_nyc);

# %%
df_json_data_311_resquests_nyc.head()
# Out:
#   Unique Key         Created Date          Closed Date Agency  \
# 0   52934953  2022-01-01T00:00:10  2022-01-01T01:00:11   NYPD
# 1   52933158  2022-01-01T00:00:57  2022-01-01T00:58:22   NYPD
# 2   52938624  2022-01-01T00:01:04  2022-01-01T00:18:49   NYPD
# 3   52931678  2022-01-01T00:01:17  2022-01-01T02:55:16   NYPD
# 4   52934960  2022-01-01T00:01:20  2022-01-01T00:07:25   NYPD
#
#                        Agency Name           Complaint Type        Descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department      Noise - Residential      Loud Talking
# 2  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 3  New York City Police Department      Noise - Residential  Loud Music/Party
# 4  New York City Police Department      Noise - Residential  Loud Music/Party
#
#                 Location Type Incident Zip      Incident Address  ...  \
# ...

# %%
#9. Merging two Data Frames.
df_311_resquests_nyc = pd.concat([df_json_data_311_resquests_nyc, df_csv_data_311_resquests_nyc])

# %%
df_311_resquests_nyc = df_csv_data_311_resquests_nyc

# %%
df_311_resquests_nyc.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    52934953  01/01/2022 12:00:10 AM  01/01/2022 01:00:11 AM   NYPD
# 1    52933158  01/01/2022 12:00:57 AM  01/01/2022 12:58:22 AM   NYPD
# 2    52938624  01/01/2022 12:01:04 AM  01/01/2022 12:18:49 AM   NYPD
# 3    52931678  01/01/2022 12:01:17 AM  01/01/2022 02:55:16 AM   NYPD
# 4    52934960  01/01/2022 12:01:20 AM  01/01/2022 12:07:25 AM   NYPD
#
#                        Agency Name           Complaint Type        Descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department      Noise - Residential      Loud Talking
# 2  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 3  New York City Police Department      Noise - Residential  Loud Music/Party
# 4  New York City Police Department      Noise - Residential  Loud Music/Party
#
#                 Location Type  Incident Zip      Incident Address  ...  \
# ...

# %%
df_311_resquests_nyc.tail()
# Out:
#          Unique Key            Created Date Closed Date Agency  \
# 2687359    55891527  11/04/2022 12:00:00 PM         NaN   DSNY
# 2687360    55883085  11/04/2022 12:00:00 PM         NaN   DSNY
# 2687361    55886682  11/04/2022 12:00:00 PM         NaN   DSNY
# 2687362    55886681  11/04/2022 12:00:00 PM         NaN   DSNY
# 2687363    55884310  11/04/2022 12:00:00 PM         NaN   DSNY
#
#                       Agency Name     Complaint Type         Descriptor  \
# 2687359  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2687360  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2687361  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2687362  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
# 2687363  Department of Sanitation  Derelict Vehicles  Derelict Vehicles
#
#         Location Type  Incident Zip    Incident Address  ... Vehicle Type  \
# 2687359        Street           NaN                 NaN  ...          NaN
# ...

# %%
df_311_resquests_nyc.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Description', 'Resolution Action Updated Date',
#        'Community Board', 'BBL', 'Borough', 'X Coordinate (State Plane)',
#        'Y Coordinate (State Plane)', 'Open Data Channel Type',
#        'Park Facility Name', 'Park Borough', 'Vehicle Type',
#        'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
#        'Latitude', 'Longitude', 'Location'],
#       dtype='object')

# %%
df_csv_data_311_resquests_nyc.dtypes
# Out:
# Unique Key                          int64
# Created Date                       object
# Closed Date                        object
# Agency                             object
# Agency Name                        object
# Complaint Type                     object
# Descriptor                         object
# Location Type                      object
# Incident Zip                      float64
# Incident Address                   object
# Street Name                        object
# Cross Street 1                     object
# Cross Street 2                     object
# Intersection Street 1              object
# Intersection Street 2              object
# Address Type                       object
# City                               object
# Landmark                           object
# Facility Type                      object
# Status                             object
# Due Date                           object
# Resolution Description             object
# ...

# %%
nycRequestDframeOp.displayEmptyColCount(df_311_resquests_nyc);
# Out:
# Closed Date                        170508.0
# Descriptor                          86597.0
# Location Type                      355552.0
# Incident Zip                        38632.0
# Incident Address                   134349.0
# Street Name                        134455.0
# Cross Street 1                     735796.0
# Cross Street 2                     736308.0
# Intersection Street 1              885277.0
# Intersection Street 2              884375.0
# Address Type                        19589.0
# City                               148291.0
# Landmark                          1110319.0
# Facility Type                     2674080.0
# Due Date                          2677425.0
# Resolution Description              84298.0
# Resolution Action Updated Date      76639.0
# BBL                                342999.0
# X Coordinate (State Plane)          44469.0
# Y Coordinate (State Plane)          44379.0
# Park Facility Name                   2009.0
# ...

# %%
#3. Drop any NULL 
df_311_resquests_nyc = nycRequestDframeOp.dropEmptyColumns(df_311_resquests_nyc)

# %%
nycRequestDframeOp.displayEmptyColCount(df_311_resquests_nyc);
# Out:
# Closed Date                        170508.0
# Descriptor                          86597.0
# Location Type                      355552.0
# Incident Zip                        38632.0
# Incident Address                   134349.0
# Street Name                        134455.0
# Cross Street 1                     735796.0
# Cross Street 2                     736308.0
# Intersection Street 1              885277.0
# Intersection Street 2              884375.0
# Address Type                        19589.0
# City                               148291.0
# Landmark                          1110319.0
# Facility Type                     2674080.0
# Due Date                          2677425.0
# Resolution Description              84298.0
# Resolution Action Updated Date      76639.0
# BBL                                342999.0
# X Coordinate (State Plane)          44469.0
# Y Coordinate (State Plane)          44379.0
# Park Facility Name                   2009.0
# ...

# %%
#3. drop unwanted columns.
df_311_resquests_nyc = nycRequestDframeOp.dropUnnecessarlyColumns(df_311_resquests_nyc)

# %%
nycRequestDframeOp.displayEmptyColCount(df_311_resquests_nyc);
# Out:
# Closed Date                       170508.0
# Location Type                     355552.0
# Incident Zip                       38632.0
# Incident Address                  134349.0
# Street Name                       134455.0
# Cross Street 1                    735796.0
# Cross Street 2                    736308.0
# Intersection Street 1             885277.0
# Intersection Street 2             884375.0
# Address Type                       19589.0
# City                              148291.0
# Resolution Description             84298.0
# Resolution Action Updated Date     76639.0
# BBL                               342999.0
# Latitude                           44486.0
# Longitude                          44486.0
# dtype: float64

# %%
df_311_resquests_nyc = nycRequestDframeOp.convertStrToDateTime('Created Date', df_311_resquests_nyc);

# %%
df_311_resquests_nyc = nycRequestDframeOp.convertStrToDateTime('Closed Date', df_311_resquests_nyc);

# %%
df_csv_data_311_resquests_nyc.dtypes
# Out:
# Unique Key                                 int64
# Created Date                      datetime64[ns]
# Closed Date                       datetime64[ns]
# Agency Name                               object
# Complaint Type                            object
# Location Type                             object
# Incident Zip                             float64
# Incident Address                          object
# Street Name                               object
# Cross Street 1                            object
# Cross Street 2                            object
# Intersection Street 1                     object
# Intersection Street 2                     object
# Address Type                              object
# City                                      object
# Status                                    object
# Resolution Description                    object
# Resolution Action Updated Date            object
# BBL                                      float64
# ...

# %%
df_311_resquests_nyc = nycRequestDframeOp.createResolutionTimeCol(df_311_resquests_nyc);

# %%
df_311_resquests_nyc = nycRequestDframeOp.createResolTimeColInMin(df_311_resquests_nyc);

# %%
#Slicing Data of a particular column value (like year, month)
df_311_resquests_nyc = nycRequestDframeOp.createMonthColFromCloseDate(df_311_resquests_nyc);

# %%
df_311_resquests_nyc.head()
# Out:
#    Unique Key        Created Date         Closed Date  \
# 0    52934953 2022-01-01 00:00:10 2022-01-01 01:00:11
# 1    52933158 2022-01-01 00:00:57 2022-01-01 00:58:22
# 2    52938624 2022-01-01 00:01:04 2022-01-01 00:18:49
# 3    52931678 2022-01-01 00:01:17 2022-01-01 02:55:16
# 4    52934960 2022-01-01 00:01:20 2022-01-01 00:07:25
#
#                        Agency Name           Complaint Type  \
# 0  New York City Police Department  Noise - Street/Sidewalk
# 1  New York City Police Department      Noise - Residential
# 2  New York City Police Department  Noise - Street/Sidewalk
# 3  New York City Police Department      Noise - Residential
# 4  New York City Police Department      Noise - Residential
#
#                 Location Type  Incident Zip      Incident Address  \
# 0             Street/Sidewalk       11222.0     126 DRIGGS AVENUE
# 1  Residential Building/House       11214.0    45 BAY   38 STREET
# 2             Street/Sidewalk       10025.0  998 AMSTERDAM AVENUE
# ...

# %%
nycRequestDframeOp.displayEmptyColCount(df_311_resquests_nyc);
# Out:
# Closed Date                       170508.0
# Location Type                     355552.0
# Incident Zip                       38632.0
# Incident Address                  134349.0
# Street Name                       134455.0
# Cross Street 1                    735796.0
# Cross Street 2                    736308.0
# Intersection Street 1             885277.0
# Intersection Street 2             884375.0
# Address Type                       19589.0
# City                              148291.0
# Resolution Description             84298.0
# Resolution Action Updated Date     76639.0
# BBL                               342999.0
# Latitude                           44486.0
# Longitude                          44486.0
# Request Resolution Time           170508.0
# Request Resolution Time in Min    170508.0
# Request Closing Month             170508.0
# dtype: float64

# %%
df_311_resquests_nyc = nycRequestDframeOp.updateColswithModeValue(df_311_resquests_nyc);

# %%
nycRequestDframeOp.displayEmptyColCount(df_311_resquests_nyc);
# Out:
# Closed Date                       170508.0
# Location Type                     355552.0
# Incident Zip                         197.0
# Incident Address                  134349.0
# Street Name                       134455.0
# Cross Street 1                    735796.0
# Cross Street 2                    736308.0
# Intersection Street 1             885277.0
# Intersection Street 2             884375.0
# Address Type                       19589.0
# Resolution Description             84298.0
# Resolution Action Updated Date     76639.0
# BBL                               342999.0
# Latitude                           12833.0
# Longitude                          12833.0
# Request Resolution Time           170508.0
# Request Resolution Time in Min    170508.0
# Request Closing Month             170508.0
# dtype: float64

# %%
#3. Drop missing values
nycRequestDframeOp.dropNaRecords(df_311_resquests_nyc);

# %%
nycRequestDframeOp.displayEmptyColCount(df_311_resquests_nyc);
# Out:
# Series([], dtype: float64)

# %%
df_311_resquests_nyc
# Out:
#          Unique Key        Created Date         Closed Date  \
# 1          52933158 2022-01-01 00:00:57 2022-01-01 00:58:22
# 2          52938624 2022-01-01 00:01:04 2022-01-01 00:18:49
# 3          52931678 2022-01-01 00:01:17 2022-01-01 02:55:16
# 4          52934960 2022-01-01 00:01:20 2022-01-01 00:07:25
# 5          52934948 2022-01-01 00:01:25 2022-01-01 00:26:49
# ...             ...                 ...                 ...
# 2687288    55886102 2022-11-04 00:37:07 2022-11-04 00:38:11
# 2687293    55884925 2022-11-04 00:38:04 2022-11-04 00:52:10
# 2687294    55889668 2022-11-04 00:38:11 2022-11-04 00:55:00
# 2687299    55888577 2022-11-04 00:39:36 2022-11-04 00:59:01
# 2687301    55889717 2022-11-04 00:40:01 2022-11-04 00:56:56
#
#                              Agency Name           Complaint Type  \
# 1        New York City Police Department      Noise - Residential
# 2        New York City Police Department  Noise - Street/Sidewalk
# ...

# %%
df_311_resquests_nyc.describe()
# Out:
#          Unique Key  Incident Zip           BBL      Latitude     Longitude  \
# count  1.397479e+06  1.397479e+06  1.397479e+06  1.397479e+06  1.397479e+06
# mean   5.448700e+07  1.081260e+04  2.731211e+09  4.074359e+01 -7.391833e+01
# std    8.058130e+05  5.309583e+02  1.153461e+09  9.002501e-02  7.605212e-02
# min    5.293153e+07  1.000000e+04  0.000000e+00  4.049892e+01 -7.425480e+01
# 25%    5.384845e+07  1.045300e+04  2.029820e+09  4.067882e+01 -7.396314e+01
# 50%    5.451274e+07  1.120100e+04  3.016530e+09  4.073320e+01 -7.391969e+01
# 75%    5.516860e+07  1.123400e+04  4.008340e+09  4.082497e+01 -7.386243e+01
# max    5.589173e+07  1.234500e+04  5.270001e+09  4.091287e+01 -7.370038e+01
#
#            Request Resolution Time  Request Resolution Time in Min  \
# count                      1397479                    1.397479e+06
# mean     2 days 09:28:36.090623902                    3.448602e+03
# std    100 days 08:58:59.686026340                    1.445390e+05
# ...

# %%
df_311_resquests_nyc = nycRequestDataPlot.createCategoricalColumns(df_311_resquests_nyc);

# %%
df_311_req_filtered_data = nycRequestDataPlot.filterDataBasedCategory(df_311_resquests_nyc, 'City Code',6,30, City_Code='City Code',Borough_Code='Borough Code',Complaint_Type_Code='Complaint Type Code');

# %%
df_311_req_filtered_data.head();

# %%
df_311_resquests_nyc_filter_data = nycRequestDataPlot.filterDataBasedOnAgencyNameTimeResCity(df_311_resquests_nyc)

# %%
df_311_resquests_nyc_filter_data
# Out:
#          Unique Key        Created Date         Closed Date  \
# 36         52934843 2022-01-01 00:06:22 2022-01-01 00:10:14
# 237        52938735 2022-01-01 00:27:17 2022-01-01 00:28:23
# 897        52933577 2022-01-01 01:42:36 2022-01-01 01:51:27
# 1071       52943518 2022-01-01 02:07:15 2022-01-01 02:16:26
# 1091       52940142 2022-01-01 02:10:50 2022-01-01 02:15:07
# ...             ...                 ...                 ...
# 2686991    55889687 2022-11-03 23:33:10 2022-11-03 23:36:02
# 2687255    55883716 2022-11-04 00:29:05 2022-11-04 00:38:07
# 2687274    55888464 2022-11-04 00:34:02 2022-11-04 00:38:10
# 2687283    55890916 2022-11-04 00:36:04 2022-11-04 00:38:09
# 2687288    55886102 2022-11-04 00:37:07 2022-11-04 00:38:11
#
#                              Agency Name               Complaint Type  \
# 36       New York City Police Department           Noise - Commercial
# 237      New York City Police Department      Noise - Street/Sidewalk
# ...

# %%
nycRequestDataPlot.getAverageResolvedTimeInMin(df_311_resquests_nyc);
# Out:
# Average Time takes to Resolved the 311 NYC issues is: 3448.6039781306035

# %%
# 11. Representing data in matrix form.
df_311_req_matrix = nycRequestDataPlot.covertDataFrToMatrix(df_311_req_filtered_data);

# %%
df_311_req_matrix;

# %%
df_311_resquests_nyc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1397479 entries, 1 to 2687301
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Unique Key                      1397479 non-null  int64
#  1   Created Date                    1397479 non-null  datetime64[ns]
#  2   Closed Date                     1397479 non-null  datetime64[ns]
#  3   Agency Name                     1397479 non-null  object
#  4   Complaint Type                  1397479 non-null  object
#  5   Location Type                   1397479 non-null  object
#  6   Incident Zip                    1397479 non-null  float64
#  7   Incident Address                1397479 non-null  object
#  8   Street Name                     1397479 non-null  object
#  9   Cross Street 1                  1397479 non-null  object
#  10  Cross Street 2                  1397479 non-null  object
# ...

# %%
df_311_resquests_nyc.describe()
# Out:
#          Unique Key  Incident Zip           BBL      Latitude     Longitude  \
# count  1.397479e+06  1.397479e+06  1.397479e+06  1.397479e+06  1.397479e+06
# mean   5.448700e+07  1.081260e+04  2.731211e+09  4.074359e+01 -7.391833e+01
# std    8.058130e+05  5.309583e+02  1.153461e+09  9.002501e-02  7.605212e-02
# min    5.293153e+07  1.000000e+04  0.000000e+00  4.049892e+01 -7.425480e+01
# 25%    5.384845e+07  1.045300e+04  2.029820e+09  4.067882e+01 -7.396314e+01
# 50%    5.451274e+07  1.120100e+04  3.016530e+09  4.073320e+01 -7.391969e+01
# 75%    5.516860e+07  1.123400e+04  4.008340e+09  4.082497e+01 -7.386243e+01
# max    5.589173e+07  1.234500e+04  5.270001e+09  4.091287e+01 -7.370038e+01
#
#            Request Resolution Time  Request Resolution Time in Min  \
# count                      1397479                    1.397479e+06
# mean     2 days 09:28:36.090623902                    3.448602e+03
# std    100 days 08:58:59.686026340                    1.445390e+05
# ...

# %%
nycRequestDataPlot.drawBarPlotCityComplaintType(df_311_resquests_nyc);

# %%
nycRequestDataPlot.drawCountPlotComplaintType(df_311_resquests_nyc);

# %%
nycRequestDataPlot.drawBarPlotAgencyComplaintType(df_311_resquests_nyc)

# %%
nycRequestDataPlot.drawCountPlotLocationType(df_311_resquests_nyc)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
nycRequestDataPlot.drawBarPlotBoroughClosingTimeMin(df_311_resquests_nyc)

# %%
nycRequestDataPlot.drawHistogramPlot(df_311_resquests_nyc);

# %%
nycRequestDataPlot.drawHeatMap(df_311_resquests_nyc);

# %%
nycRequestDataPlot.drawHeatMapCorr(df_311_resquests_nyc);

# %%
nycRequestDataPlot.drawPairPlot(df_311_resquests_nyc);

# %%
nycRequestDataPlot.drawScatterPlot(df_311_resquests_nyc);

# %%
numPyarray_311_req = nycRequestDataPlot.updloadDataToNumpy(df_311_resquests_nyc);

# %%
numPyarray_311_req
# Out:
# array([[52933158, Timestamp('2022-01-01 00:00:57'),
#         Timestamp('2022-01-01 00:58:22'), ..., 66, 6, 1],
#        [52938624, Timestamp('2022-01-01 00:01:04'),
#         Timestamp('2022-01-01 00:18:49'), ..., 67, 30, 2],
#        [52931678, Timestamp('2022-01-01 00:01:17'),
#         Timestamp('2022-01-01 02:55:16'), ..., 66, 5, 0],
#        ...,
#        [55889668, Timestamp('2022-11-04 00:38:11'),
#         Timestamp('2022-11-04 00:55:00'), ..., 62, 30, 2],
#        [55888577, Timestamp('2022-11-04 00:39:36'),
#         Timestamp('2022-11-04 00:59:01'), ..., 68, 6, 1],
#        [55889717, Timestamp('2022-11-04 00:40:01'),
#         Timestamp('2022-11-04 00:56:56'), ..., 66, 15, 3]], dtype=object)

# %%
numPyarray_311_req_slice_data = nycRequestDataPlot.sliceAndDisplayData(numPyarray_311_req);

# %%
numPyarray_311_req_slice_data
# Out:
# array([[Timestamp('2022-01-01 00:00:57'),
#         Timestamp('2022-01-01 00:58:22'),
#         'New York City Police Department'],
#        [Timestamp('2022-01-01 00:01:04'),
#         Timestamp('2022-01-01 00:18:49'),
#         'New York City Police Department'],
#        [Timestamp('2022-01-01 00:01:17'),
#         Timestamp('2022-01-01 02:55:16'),
#         'New York City Police Department'],
#        [Timestamp('2022-01-01 00:01:20'),
#         Timestamp('2022-01-01 00:07:25'),
#         'New York City Police Department'],
#        [Timestamp('2022-01-01 00:01:25'),
#         Timestamp('2022-01-01 00:26:49'),
#         'New York City Police Department'],
#        [Timestamp('2022-01-01 00:01:47'),
#         Timestamp('2022-01-01 00:19:05'),
#         'New York City Police Department'],
#        [Timestamp('2022-01-01 00:02:21'),
#         Timestamp('2022-01-01 00:49:06'),
#         'New York City Police Department'],
#        [Timestamp('2022-01-01 00:02:25'),
# ...
